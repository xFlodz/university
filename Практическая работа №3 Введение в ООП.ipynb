# %% [markdown]
# <a href="https://colab.research.google.com/github/xFlodz/university/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%20%E2%84%963%20%D0%92%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%B2%20%D0%9E%D0%9E%D0%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Практическая работа №3. Введение в ООП**

# %% [markdown]
# ## **Задание №1. Создайте класс Sphere для представления сферы в трехмерном пространстве**

# %% [markdown]
# Обеспечьте следующие методы класса:
#
# 1. Конструктор, принимающий 4 действительных числа: радиус, и 3 координаты центра шара. Если конструктор вызывается без аргументов, создать объект сферы с единичным радиусом и центром в начале координат. Если конструктор вызывается с аргументом, создать объект сферы с соответствующим радиусом и центром в начале координат.
#
# 2. Метод get_volume (), который возвращает действительное число — объем шара, ограниченной текущей сферой.
#
# 3. Метод get_square (), который возвращает действительное число — площадь внешней поверхности сферы.
#
# 4. Метод get_radius (), который возвращает действительное число — радиус сферы.
#
# 5. Метод get_center (), который возвращает тьюпл с 3 действительными числами — координатами центра сферы в том же порядке, в каком они задаются в конструкторе.
#
# 6. Метод set_radius (r), который принимает 1 аргумент — действительное число, и меняет радиус текущей сферы, ничего не возвращая.
#
# 7. Метод set_center (x, y, z), который принимает 3 аргумента — действительных числа, и меняет координаты центра сферы, ничего не возвращая. Координаты задаются в том же порядке, что и в конструкторе.
#
# 8. Метод is_point_inside (x, y, z), который принимает 3 аргумента — действительных числа — координаты некоторой точки в пространстве (в том же порядке, что и в конструкторе), и возвращает логическое значение True или False в зависимости от того, находится эта точка внутри сферы.

# %%
# Тесты

s0 = Sphere(0.5) # test sphere creation with radius and default center
print(s0.get_center()) # (0.0, 0.0, 0.0)
print(s0.get_volume()) # 0.523598775598
print(s0.is_point_inside(0 , -1.5, 0)) # False
s0.set_radius(1.6)
print(s0.is_point_inside(0, -1.5, 0)) # True
print(s0.get_radius()) # 1.6
# Out:
# (0.0, 0.0, 0.0)
# 0.5235987755982988
# False
# True
# 1.6

# %%
import math

class Sphere:
    def __init__(self, radius=1.0, x=0.0, y=0.0, z=0.0):
        self.radius = radius
        self.center = (x, y, z)

    def get_volume(self):
        return (4.0 / 3.0) * math.pi * (self.radius ** 3)

    def get_square(self):
        return 4.0 * math.pi * (self.radius ** 2)

    def get_radius(self):
        return self.radius

    def get_center(self):
        return self.center

    def set_radius(self, r):
        self.radius = r

    def set_center(self, x, y, z):
        self.center = (x, y, z)

    def is_point_inside(self, x, y, z):
        dx = x - self.center[0]
        dy = y - self.center[1]
        dz = z - self.center[2]
        distance_squared = dx**2 + dy**2 + dz**2
        return distance_squared <= self.radius**2

# %% [markdown]
# ## **Задание №2. Создайте класс SuperStr, который наследует стандартный класс str и содержит 2 новых метода:**

# %% [markdown]
# 1. Метод is_repeatance (s), который принимает 1 аргумент s и возвращает True или False в зависимости от того, может ли текущая строку быть получена целым количеством повторов строки s. Вернуть False, если s не является строкой. Считать, что пустая строка не содержит повторов.
#
# 2. Метод is_palindrom (), который возвращает True или False в зависимости от того, является ли строка [палиндромом](https://ru.wikipedia.org/wiki/Палиндром). Регистрами символов пренебрегать. Пустую строку считать палиндромом.

# %%
class SuperStr(str):
    def is_repeatance(self, s):
        if not isinstance(s, str):
            return False
        if not self or not s:
            return False
        if len(self) % len(s) != 0:
            return False
        return self == s * (len(self) // len(s))

    def is_palindrom(self):
        last_c = len(self) - 1
        c = 0
        while c != last_c:
            if self[c] != self[last_c]:
                return False
            c += 1
            last_c -= 1
        return True

    #def is_palindrom(self):
        #return self.lower() == self.lower()[::-1]

# %%
# Тесты

s = SuperStr("123123123123")
print(s.is_repeatance("123")) # True
print(s.is_repeatance("123123")) # True
print(s.is_repeatance("123123123123")) # True
print(s.is_repeatance("12312")) # False
print(s.is_repeatance(123)) # False
print(s.is_palindrom()) # False
print(s) # 123123123123 (строка)
print(int(s)) # 123123123123 (целое число)
print(s + "qwe") # 123123123123qwe
p = SuperStr("123_321")
print(p.is_palindrom()) # True
# Out:
# True
# True
# True
# False
# False
# False
# 123123123123
# 123123123123
# 123123123123qwe
# True

# %% [markdown]
# ## **Задание №3. В коде ниже представлен класс преподавателей и класс студентов (вы можете взять этот код за основу или написать свой).**

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

# %%
best_student = Student('Ruoy', 'Eman', 'your_gender')
cool_mentor = Mentor('Some', 'Buddy')
cool_mentor.rate_hw(best_student, 'Python', 10)

print("Имя студента: ", best_student.name)
print("Имя преподавателя: ", cool_mentor.name)
print("Оценки студента по курсам: ", best_student.grades)
# Out:
# Имя студента:  Ruoy
# Имя преподавателя:  Some
# Оценки студента по курсам:  {'Python': [10]}

# %% [markdown]
# ### **3.1. Наследование**

# %% [markdown]
# * Класс Mentor должен стать родительским классом для преподавателей. От него нужно реализовать наследование классов Lecturer (лекторы) и Reviewer (эксперты, проверяющие домашние задания).
#
# > Имя, фамилю и список закрепленных курсов логично реализовать на уровне родительского класса.

# %%
class Lecturer(Mentor):
    pass


class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if (course in self.courses_attached and
            course in student.courses_in_progress and
            course not in student.finished_courses):

            if course in student.grades:
                student.grades[course].append(grade)
            else:
                student.grades[course] = [grade]
            return f"Ревьювер {self.name} {self.surname} проверил ДЗ и выставил оценку {grade} по курсу {course}"
        else:
            return 'Ошибка: ревьювер не может проверить это ДЗ'

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"

    def __lt__(self, other):
        """Сравнение ревьюверов по количеству курсов (меньше)"""
        if isinstance(other, Reviewer):
            return len(self.courses_attached) < len(other.courses_attached)
        return NotImplemented

    def __gt__(self, other):
        """Сравнение ревьюверов по количеству курсов (больше)"""
        if isinstance(other, Reviewer):
            return len(self.courses_attached) > len(other.courses_attached)
        return NotImplemented

    def __len__(self):
        """Количество курсов, закрепленных за ревьювером"""
        return len(self.courses_attached)

# %%
student = Student('Ruoy', 'Eman', 'male')
student.courses_in_progress = ['Python', 'Git']
student.finished_courses = ['Введение в программирование']

lecturer = Lecturer('Ivan', 'Petrov')
reviewer = Reviewer('Maria', 'Sidorova')

lecturer.courses_attached = ['Python', 'Git']
reviewer.courses_attached = ['Python', 'Git']

print("\nРевьювер проверяет:")
print(reviewer.rate_hw(student, 'Git', 8))
print(reviewer.rate_hw(student, 'Git', 9))

print("\nПроверка ошибок:")
print(reviewer.rate_hw(student, 'Java', 7)) #Ревьювер не знает Java

print(f"\nИтоговые оценки студента: {student.grades}")
# Out:
# Ревьювер проверяет:
# Ревьювер Maria Sidorova проверил ДЗ и выставил оценку 8 по курсу Git
# Ревьювер Maria Sidorova проверил ДЗ и выставил оценку 9 по курсу Git
#
# Проверка ошибок:
# Ошибка: ревьювер не может проверить это ДЗ
#
# Итоговые оценки студента: {'Git': [8, 9]}

# %% [markdown]
# ### **3.2. Атрибуты и взаимодействие классов**

# %% [markdown]
# * Реализуйте возможность проставления оценок студентам только Reviewer-ам (реализуйте такой метод).
#
# * Реализуйте метод выставления оценок лекторам у класса Student (оценки по 10-балльной шкале, хранятся в атрибуте-словаре у Lecturer, в котором ключи – названия курсов, а значения – списки оценок). Лектор при этом должен быть закреплен за тем курсом, на который записан студент (реализовать проверку).

# %%
class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

    def rate_hw(self):
        return f"Вы лектор, вы не можете оценивать студентов"

    def get_average_grade(self):
        all_grades = []
        for course_grades in self.grades.values():
            all_grades.extend(course_grades)
        return sum(all_grades) / len(all_grades) if all_grades else 0

    def __str__(self):
        all_grades = []
        for course_grades in self.grades.values():
            all_grades.extend(course_grades)
        avg_grade = sum(all_grades) / len(all_grades) if all_grades else 0

        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}\n"
                f"Средняя оценка за лекции: {avg_grade:.1f}")

    def __lt__(self, other):
        """Сравнение лекторов по среднему баллу (меньше)"""
        if isinstance(other, Lecturer):
            return self.get_average_grade() < other.get_average_grade()
        return NotImplemented

    def __gt__(self, other):
        """Сравнение лекторов по среднему баллу (больше)"""
        if isinstance(other, Lecturer):
            return self.get_average_grade() > other.get_average_grade()
        return NotImplemented

    def __eq__(self, other):
        """Сравнение лекторов по среднему баллу (равенство)"""
        if isinstance(other, Lecturer):
            return abs(self.get_average_grade() - other.get_average_grade()) < 0.1
        return NotImplemented

class NewStudent(Student):
      def rate_lecturer(self, lecturer, course, grade):
        if (course in self.courses_in_progress and
            course in lecturer.courses_attached and
            course not in self.finished_courses and
            1 <= grade <= 10):

            if course in lecturer.grades:
                lecturer.grades[course].append(grade)
            else:
                lecturer.grades[course] = [grade]
            return f"Студент {self.name} {self.surname} оценил лектора {lecturer.name} {lecturer.surname} на {grade} баллов"
        else:
            return 'Ошибка: студент не может оценить этого лектора'

      def get_average_grade(self):
        all_grades = []
        for course_grades in self.grades.values():
            all_grades.extend(course_grades)
        return sum(all_grades) / len(all_grades) if all_grades else 0


      def __str__(self):
        courses_in_progress_str = ', '.join(self.courses_in_progress)
        finished_courses_str = ', '.join(self.finished_courses)

        all_grades = []
        for course_grades in self.grades.values():
            all_grades.extend(course_grades)
        avg_grade = sum(all_grades) / len(all_grades) if all_grades else 0

        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}\n"
                f"Средняя оценка за домашние задания: {avg_grade:.1f}\n"
                f"Курсы в процессе изучения: {courses_in_progress_str}\n"
                f"Завершенные курсы: {finished_courses_str}")

      def __lt__(self, other):
        """Сравнение студентов по среднему баллу (меньше)"""
        if isinstance(other, Student):
            return self.get_average_grade() < other.get_average_grade()
        return NotImplemented

      def __gt__(self, other):
        """Сравнение студентов по среднему баллу (больше)"""
        if isinstance(other, Student):
            return self.get_average_grade() > other.get_average_grade()
        return NotImplemented

      def __eq__(self, other):
        """Сравнение студентов по среднему баллу (равенство)"""
        if isinstance(other, Student):
            return abs(self.get_average_grade() - other.get_average_grade()) < 0.1
        return NotImplemented

      def __len__(self):
        """Количество курсов, которые изучает студент"""
        return len(self.courses_in_progress)

# %%
student1 = NewStudent('Ruoy', 'Eman', 'male')
student1.courses_in_progress = ['Python', 'Git']

student2 = NewStudent('Anna', 'Ivanova', 'female')
student2.courses_in_progress = ['Python', 'JavaScript']

lecturer = Lecturer('Ivan', 'Petrov')
lecturer.courses_attached = ['Python', 'Git']

reviewer = Reviewer('Maria', 'Sidorova')
reviewer.courses_attached = ['Python', 'Git']

print("\nReviewer оценивает студентов")
print(reviewer.rate_hw(student1, 'Python', 9))
print(reviewer.rate_hw(student1, 'Python', 10))
print(reviewer.rate_hw(student1, 'Git', 8))
print(reviewer.rate_hw(student2, 'Python', 7))

print("\nСтуденты оценивают лектора")
print(student1.rate_lecturer(lecturer, 'Python', 10))
print(student1.rate_lecturer(lecturer, 'Python', 9))
print(student2.rate_lecturer(lecturer, 'Python', 8))
print(student1.rate_lecturer(lecturer, 'Git', 9))

print("\nПроверка ошибок")
# Студент пытается оценить лектора по курсу, который не изучает
print(student2.rate_lecturer(lecturer, 'Git', 10))

# Reviewer пытается оценить курс который не знает
print(reviewer.rate_hw(student1, 'JavaScript', 6))

# Некорректная оценка
print(student1.rate_lecturer(lecturer, 'Python', 15))

print(f"\n{'-' * 20}")
print(f"Оценки студента {student1.name}: {student1.grades}")
print(f"Оценки студента {student2.name}: {student2.grades}")
print(f"Оценки лектора {lecturer.name}: {lecturer.grades}")
# Out:
# Reviewer оценивает студентов
# Ревьювер Maria Sidorova проверил ДЗ и выставил оценку 9 по курсу Python
# Ревьювер Maria Sidorova проверил ДЗ и выставил оценку 10 по курсу Python
# Ревьювер Maria Sidorova проверил ДЗ и выставил оценку 8 по курсу Git
# Ревьювер Maria Sidorova проверил ДЗ и выставил оценку 7 по курсу Python
#
# Студенты оценивают лектора
# Студент Ruoy Eman оценил лектора Ivan Petrov на 10 баллов
# Студент Ruoy Eman оценил лектора Ivan Petrov на 9 баллов
# Студент Anna Ivanova оценил лектора Ivan Petrov на 8 баллов
# Студент Ruoy Eman оценил лектора Ivan Petrov на 9 баллов
#
# Проверка ошибок
# Ошибка: студент не может оценить этого лектора
# Ошибка: ревьювер не может проверить это ДЗ
# Ошибка: студент не может оценить этого лектора
#
# --------------------
# Оценки студента Ruoy: {'Python': [9, 10], 'Git': [8]}
# Оценки студента Anna: {'Python': [7]}
# Оценки лектора Ivan: {'Python': [10, 9, 8], 'Git': [9]}

# %% [markdown]
# ### **3.3. Полиморфизм и магические методы**

# %% [markdown]
# Перегрузите магический метод \_\_str__ у всех классов.
# У проверяющих он должен выводить информацию в следующем виде:
#
#
#
# ```
# print(some_reviewer)
# Имя: Some
# Фамилия: Buddy
# ```
#
# У лекторов:
#
#
#
# ```
# print(some_lecturer)
# Имя: Some
# Фамилия: Buddy
# Средняя оценка за лекции: 9.9
# ```
#
# А у студентов так:
#
#
#
# ```
# print(some_student)
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 9.9
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование
# ```

# %%
student = NewStudent('Ruoy', 'Eman', 'male')
student.courses_in_progress = ['Python', 'Git', 'Java']
student.finished_courses = ['Введение в программирование']
student.grades = {'Python': [9, 10, 8], 'Git': [7, 8]}

lecturer = Lecturer('Ivan', 'Petrov')
lecturer.courses_attached = ['Python', 'Git']
lecturer.grades = {'Python': [10, 9, 8], 'Git': [9, 10]}

reviewer = Reviewer('Maria', 'Sidorova')
reviewer.courses_attached = ['Python', 'Git']

print("\nReviewer")
print(reviewer)

print("\nLecturer")
print(lecturer)

print("\nStudent")
print(student)
# Out:
# Reviewer
# Имя: Maria
# Фамилия: Sidorova
#
# Lecturer
# Имя: Ivan
# Фамилия: Petrov
# Средняя оценка за лекции: 9.2
#
# Student
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 8.4
# Курсы в процессе изучения: Python, Git, Java
# Завершенные курсы: Введение в программирование

# %% [markdown]
# **Реализуйте перегрузку других магических методов на Ваш выбор (не менее трёх), руководствуясь по смыслу контекстом представленных классов (студенты, преподаватели, оценки и т.д.)**

# %%
student1 = NewStudent('Ruoy', 'Eman', 'male')
student1.courses_in_progress = ['Python', 'Git', 'Java']
student1.grades = {'Python': [9, 10, 8], 'Git': [7, 8]}

student2 = NewStudent('Anna', 'Ivanova', 'female')
student2.courses_in_progress = ['Python', 'JavaScript']
student2.grades = {'Python': [8, 9, 7], 'JavaScript': [9, 10]}


lecturer1 = Lecturer('Ivan', 'Petrov')
lecturer1.courses_attached = ['Python', 'Git']
lecturer1.grades = {'Python': [10, 9, 8], 'Git': [9, 10]}

lecturer2 = Lecturer('Maria', 'Sidorova')
lecturer2.courses_attached = ['Python', 'JavaScript']
lecturer2.grades = {'Python': [8, 9, 7], 'JavaScript': [10, 9]}


reviewer1 = Reviewer('Alex', 'Brown')
reviewer1.courses_attached = ['Python', 'Git', 'Java']

reviewer2 = Reviewer('Olga', 'Smith')
reviewer2.courses_attached = ['Python']

print("1. Сравнение студентов (все операторы):")
print(f"student1 < student2:  {student1 < student2}")
print(f"student1 > student2:  {student1 > student2}")
print(f"student1 == student2: {student1 == student2}")
print(f"student1 != student2: {student1 != student2}")

print(f"\nСредние баллы: student1={student1.get_average_grade():.1f}, "
      f"student2={student2.get_average_grade():.1f}")

print("\n2. Сравнение лекторов (все операторы):")
print(f"lecturer1 < lecturer2:  {lecturer1 < lecturer2}")
print(f"lecturer1 > lecturer2:  {lecturer1 > lecturer2}")
print(f"lecturer1 == lecturer2: {lecturer1 == lecturer2}")
print(f"lecturer1 != lecturer2: {lecturer1 != lecturer2}")

print(f"\nСредние баллы: lecturer1={lecturer1.get_average_grade():.1f}, "
      f"lecturer2={lecturer2.get_average_grade():.1f}")

print("\n3. Сравнение ревьюверов (все операторы):")
print(f"reviewer1 < reviewer2:  {reviewer1 < reviewer2}")
print(f"reviewer1 > reviewer2:  {reviewer1 > reviewer2}")


print(f"\nКоличество курсов: reviewer1={len(reviewer1)}, reviewer2={len(reviewer2)}")

print("\n4. Сортировка студентов по успеваемости:")
students = [student1, student2]
sorted_students = sorted(students)
print("Отсортированные студенты (по возрастанию):")
for i, student in enumerate(sorted_students, 1):
      print(f"{i}. {student.name} {student.surname} - {student.get_average_grade():.1f}")

print("\n5. Сортировка лекторов по рейтингу:")
lecturers = [lecturer1, lecturer2]
sorted_lecturers = sorted(lecturers)
for i, lecturer in enumerate(sorted_lecturers, 1):
      print(f"{i}. {lecturer.name} {lecturer.surname} - {lecturer.get_average_grade():.1f}")
# Out:
# 1. Сравнение студентов (все операторы):
# student1 < student2:  True
# student1 > student2:  False
# student1 == student2: False
# student1 != student2: True
#
# Средние баллы: student1=8.4, student2=8.6
#
# 2. Сравнение лекторов (все операторы):
# lecturer1 < lecturer2:  False
# lecturer1 > lecturer2:  True
# lecturer1 == lecturer2: False
# lecturer1 != lecturer2: True
#
# Средние баллы: lecturer1=9.2, lecturer2=8.6
#
# 3. Сравнение ревьюверов (все операторы):
# reviewer1 < reviewer2:  False
# reviewer1 > reviewer2:  True
#
# Количество курсов: reviewer1=3, reviewer2=1
#
# 4. Сортировка студентов по успеваемости:
# Отсортированные студенты (по возрастанию):
# 1. Ruoy Eman - 8.4
# 2. Anna Ivanova - 8.6
#
# 5. Сортировка лекторов по рейтингу:
# 1. Maria Sidorova - 8.6
# 2. Ivan Petrov - 9.2

# %% [markdown]
# ### **3.4. Тестирование**
#
# Создайте по 2 экземпляра каждого класса, вызовите все созданные методы, а также реализуйте две функции:
#
# * для подсчета средней оценки за домашние задания по всем студентам в рамках конкретного курса (в качестве аргументов принимаем список студентов и название курса);
# * для подсчета средней оценки за лекции всех лекторов в рамках курса (в качестве аргумента принимаем список лекторов и название курса).

# %%
class GradeCalculator:

    @staticmethod
    def calculate_students_course_average(students, course_name):
        course_grades = []

        for student in students:
            if course_name in student.grades and student.grades[course_name]:
                course_grades.extend(student.grades[course_name])

        if course_grades:
            average = sum(course_grades) / len(course_grades)
            return round(average, 1)
        return 0

    @staticmethod
    def calculate_lecturers_course_average(lecturers, course_name):
        course_grades = []

        for lecturer in lecturers:
            if course_name in lecturer.grades and lecturer.grades[course_name]:
                course_grades.extend(lecturer.grades[course_name])

        if course_grades:
            average = sum(course_grades) / len(course_grades)
            return round(average, 1)
        return 0

# %%
student1 = Student('Ruoy', 'Eman', 'male')
student1.courses_in_progress = ['Python', 'Git']
student1.grades = {'Python': [9, 10, 8, 7], 'Git': [8, 9]}

student2 = Student('Anna', 'Ivanova', 'female')
student2.courses_in_progress = ['Python', 'JavaScript']
student2.grades = {'Python': [8, 9, 10], 'JavaScript': [7, 8, 9]}

student3 = Student('Petr', 'Sidorov', 'male')
student3.courses_in_progress = ['Python', 'Git']
student3.grades = {'Python': [10, 9, 10],'Git': [9, 8, 10]}

lecturer1 = Lecturer('Ivan', 'Petrov')
lecturer1.courses_attached = ['Python', 'Git']
lecturer1.grades = {'Python': [10, 9, 8],'Git': [9, 10]}

lecturer2 = Lecturer('Maria', 'Sidorova')
lecturer2.courses_attached = ['Python', 'JavaScript']
lecturer2.grades = {'Python': [8, 9, 7], 'JavaScript': [10, 9, 8]}

lecturer3 = Lecturer('Alex', 'Brown')
lecturer3.courses_attached = ['Python']
lecturer3.grades = {'Python': [10, 10, 9]}

students_list = [student1, student2, student3]
lecturers_list = [lecturer1, lecturer2, lecturer3]

print("1. Средние оценки студентов по курсам:")
python_students_avg = GradeCalculator.calculate_students_course_average(students_list, 'Python')
git_students_avg = GradeCalculator.calculate_students_course_average(students_list, 'Git')
js_students_avg = GradeCalculator.calculate_students_course_average(students_list, 'JavaScript')

print(f"Курс 'Python': {python_students_avg}")
print(f"Курс 'Git': {git_students_avg}")
print(f"Курс 'JavaScript': {js_students_avg}")

print("\n2. Средние оценки лекторов по курсам:")
python_lecturers_avg = GradeCalculator.calculate_lecturers_course_average(lecturers_list, 'Python')
git_lecturers_avg = GradeCalculator.calculate_lecturers_course_average(lecturers_list, 'Git')
js_lecturers_avg = GradeCalculator.calculate_lecturers_course_average(lecturers_list, 'JavaScript')

print(f"Курс 'Python': {python_lecturers_avg}")
print(f"Курс 'Git': {git_lecturers_avg}")
print(f"Курс 'JavaScript': {js_lecturers_avg}")
# Out:
# 1. Средние оценки студентов по курсам:
# Курс 'Python': 9.0
# Курс 'Git': 8.8
# Курс 'JavaScript': 8.0
#
# 2. Средние оценки лекторов по курсам:
# Курс 'Python': 8.9
# Курс 'Git': 9.5
# Курс 'JavaScript': 9.0

# %% [markdown]
# ## **Задание №4. Перегрузка операторов с помощью магических методов**

# %% [markdown]
# ### **Цель задания:**

# %% [markdown]
# Разработать класс `Fraction` для работы с рациональными числами (дробями), реализовав перегрузку стандартных операторов через переопределение соответствующих магических методов. Ваша задача — обеспечить класс `Fraction` функциональностью, демонстрируемой в приведенном примере кода.

# %% [markdown]
# ### **Описание задания:**

# %% [markdown]
# Создайте класс `Fraction`, который представляет собой обыкновенную дробь с числителем и знаменателем. Перегрузите основные арифметические операторы для выполнения операций над дробями, а также операторы сравнения. Обеспечьте возможность преобразования дроби в число с плавающей точкой и обратную операцию. Реализуйте обработку исключений при некорректных данных. Предоставьте понятное строковое и официальное представление дроби.

# %% [markdown]
# **Требования к заданию:**

# %% [markdown]
# 1. **Класс `Fraction` должен:**
#
#    - Инициализироваться двумя целыми числами: числителем и знаменателем.
#    - Обрабатывать ситуацию когда знаменатель равен нулю, а именно выводить сообщение `"Знаменатель не может быть нулем"`.
#    - Упрощать дроби до несократимых при создании и после каждой арифметической операции.
#
# 2. **Перегрузить следующие операторы путем переопределения магических методов:**
#
#    - **Сложение `+`** (`__add__`): сложение двух дробей, возвращает новую дробь.
#    - **Вычитание `-`** (`__sub__`): вычитание одной дроби из другой, возвращает новую дробь.
#    - **Умножение `*`** (`__mul__`): умножение двух дробей, возвращает новую дробь.
#    - **Деление `/`** (`__truediv__`): деление одной дроби на другую, возвращает новую дробь.
#    - **Равенство `==`** (`__eq__`): проверка равенства двух дробей.
#    - **Сравнения `>`, `<`, `>=`, `<=`**: сравнение дробей по их значению, реализовать методы `__lt__`, `__le__`, `__gt__`, `__ge__`.
#
# 3. **Реализовать преобразование типов:**
#
#    - **Метод `__float__`**: преобразование дроби в число с плавающей точкой.
#
# 4. **Дополнительные методы класса:**
#
#    - **`reciprocal()`**: возвращает новую дробь, обратную данной (числитель и знаменатель меняются местами).
#    - **Строковое представление** (`__str__`): возвращает строку вида `"числитель/знаменатель"`. Если знаменатель равен 1, возвращает только числитель в виде строки.
#    - **Официальное представление** (`__repr__`): возвращает строку вида `"Fraction(числитель, знаменатель)"`.
#
# 5. **Обработка исключений:**
#
#    - При попытке создать дробь с нулевым знаменателем выводить в консоль сообщение `ValueError`.
#    - При попытке деления на нулевую дробь, выводить в консоль сообщение `ZeroDivisionError`.
#
# 6. **Тестирование:**
#
#    - Написать код, демонстрирующий работу всех реализованных методов и операторов, используя примеры, приведенные ниже.
#    - Обеспечить корректную обработку исключений и вывод соответствующих сообщений.

# %%
import math

class Fraction:
    def __init__(self, numerator, denominator=1):
        if denominator == 0:
            raise ValueError("Знаменатель не может быть нулем")

        self.numerator = numerator
        self.denominator = denominator
        self._simplify()

    def _simplify(self):
        """Упрощает дробь до несократимого вида"""
        if self.numerator == 0:
            self.denominator = 1
            return

        num1 = abs(self.numerator)
        num2 = abs(self.denominator)

        greatest_common_divisor = math.gcd(num1, num2)

        self.numerator = self.numerator // greatest_common_divisor
        self.denominator = self.denominator // greatest_common_divisor

        if self.denominator < 0:
            self.numerator = -self.numerator
            self.denominator = -self.denominator

    @classmethod
    def from_float(cls, float_num):
        """Создает дробь из числа с плавающей точкой"""
        denominator = 1000000
        numerator = int(float_num * denominator)
        return cls(numerator, denominator)

    def reciprocal(self):
        """Возвращает обратную дробь"""
        if self.numerator == 0:
            raise ZeroDivisionError("Невозможно получить обратную дробь для нуля")
        return Fraction(self.denominator, self.numerator)

    def __add__(self, other):
        if isinstance(other, int):
            other = Fraction(other)
        elif isinstance(other, float):
            other = Fraction.from_float(other)

        new_numerator = (self.numerator * other.denominator +
                        other.numerator * self.denominator)
        new_denominator = self.denominator * other.denominator
        return Fraction(new_numerator, new_denominator)

    def __sub__(self, other):
        if isinstance(other, int):
            other = Fraction(other)
        elif isinstance(other, float):
            other = Fraction.from_float(other)

        new_numerator = (self.numerator * other.denominator -
                        other.numerator * self.denominator)
        new_denominator = self.denominator * other.denominator
        return Fraction(new_numerator, new_denominator)

    def __mul__(self, other):
        if isinstance(other, int):
            other = Fraction(other)
        elif isinstance(other, float):
            other = Fraction.from_float(other)

        new_numerator = self.numerator * other.numerator
        new_denominator = self.denominator * other.denominator
        return Fraction(new_numerator, new_denominator)

    def __truediv__(self, other):
        if isinstance(other, int):
            other = Fraction(other)
        elif isinstance(other, float):
            other = Fraction.from_float(other)

        if other.numerator == 0:
            raise ZeroDivisionError("Деление на ноль")
        return self * other.reciprocal()

    def __eq__(self, other):
        if isinstance(other, int):
            other = Fraction(other)
        elif isinstance(other, float):
            other = Fraction.from_float(other)

        return (self.numerator == other.numerator and
                self.denominator == other.denominator)

    def __lt__(self, other):
        if isinstance(other, int):
            other = Fraction(other)
        elif isinstance(other, float):
            other = Fraction.from_float(other)

        return (self.numerator * other.denominator <
                other.numerator * self.denominator)

    def __le__(self, other):
        if isinstance(other, int):
            other = Fraction(other)
        elif isinstance(other, float):
            other = Fraction.from_float(other)

        return (self.numerator * other.denominator <=
                other.numerator * self.denominator)

    def __gt__(self, other):
        if isinstance(other, int):
            other = Fraction(other)
        elif isinstance(other, float):
            other = Fraction.from_float(other)

        return (self.numerator * other.denominator >
                other.numerator * self.denominator)

    def __ge__(self, other):
        if isinstance(other, int):
            other = Fraction(other)
        elif isinstance(other, float):
            other = Fraction.from_float(other)

        return (self.numerator * other.denominator >=
                other.numerator * self.denominator)

    def __float__(self):
        return self.numerator / self.denominator

    def __int__(self):
        return self.numerator // self.denominator

    def __str__(self):
        if self.denominator == 1:
            return str(self.numerator)
        return f"{self.numerator}/{self.denominator}"

    def __repr__(self):
        return f"Fraction({self.numerator}, {self.denominator})"

# %% [markdown]
# **Тесты для класса `Fraction`:**

# %%
# Создание дробей
f1 = Fraction(3, 4)
f2 = Fraction(5, 6)

# Сложение дробей
f3 = f1 + f2
print(f3)  # Ожидаемый вывод: 19/12

# Вычитание дробей
f4 = f1 - f2
print(f4)  # Ожидаемый вывод: -1/12

# Умножение дробей
f5 = f1 * f2
print(f5)  # Ожидаемый вывод: 5/8

# Деление дробей
f6 = f1 / f2
print(f6)  # Ожидаемый вывод: 9/10

# Проверка равенства
print(f1 == Fraction(6, 8))   # Ожидаемый вывод: True

# Сравнение дробей
print(f1 > f2)    # Ожидаемый вывод: False
print(f1 < f2)    # Ожидаемый вывод: True

# Преобразование к float
print(float(f1))  # Ожидаемый вывод: 0.75

# Обратная дробь
f7 = f1.reciprocal()
print(f7)         # Ожидаемый вывод: 4/3

# Создание дроби из float
f8 = Fraction.from_float(0.75)
print(f8)         # Ожидаемый вывод: 3/4

# Проверка обработки исключений
try:
    f_invalid = Fraction(5, 0)
except ValueError as e:
    print(e)  # Ожидаемый вывод: Знаменатель не может быть нулем

# Строковое и официальное представление
print(str(f1))    # Ожидаемый вывод: 3/4
print(repr(f1))   # Ожидаемый вывод: Fraction(3, 4)
# Out:
# 19/12
# -1/12
# 5/8
# 9/10
# True
# False
# True
# 0.75
# 4/3
# 3/4
# Знаменатель не может быть нулем
# 3/4
# Fraction(3, 4)
